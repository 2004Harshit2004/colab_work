# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !ls
# Out:
# ActivationFunction.ipynb		 perceptron.ipynb
# Implementation_of_ANN_using_Keras.ipynb  Untitled0.ipynb

# %%
# !git config --global user.email "harsitgoswami974@gmail.com"
# !git config --global user.name "2004Harshit2004"
